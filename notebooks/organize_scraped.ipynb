# %%
import pandas as pd
from os.path import join, exists
import os
import numpy as np

root = r'results'
filenames = os.listdir(root)
filepaths = [join(root, filenames)]

print(f'Found {len(filenames)} files in {root}.\n')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\ML_projects\IPV-Scraper\utils\organize_scraped.py in <module>
#       <a href='file:///d%3A/ML_projects/IPV-Scraper/utils/organize_scraped.py?line=4'>5</a> import numpy as np
#       <a href='file:///d%3A/ML_projects/IPV-Scraper/utils/organize_scraped.py?line=6'>7</a> root = r'results'
# ----> <a href='file:///d%3A/ML_projects/IPV-Scraper/utils/organize_scraped.py?line=7'>8</a> filenames = os.listdir(root)
#       <a href='file:///d%3A/ML_projects/IPV-Scraper/utils/organize_scraped.py?line=8'>9</a> filepaths = [join(root, filenames)]
#      <a href='file:///d%3A/ML_projects/IPV-Scraper/utils/organize_scraped.py?line=10'>11</a> print(f'Found {len(filenames)} files in {root}.\n')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'results'
